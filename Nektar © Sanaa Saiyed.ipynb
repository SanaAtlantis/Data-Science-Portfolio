# %%
# prompt: write a programme which can generates a heatmap of which places in the world need food and water.

# !pip install geopandas matplotlib folium

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

# Sample data (replace with real data)
data = {
    'country': ['USA', 'Canada', 'Mexico', 'Brazil', 'India'],
    'latitude': [37.0902, 56.1304, 23.6345, -14.2350, 20.5937],
    'longitude': [-95.7129, -106.3468, -102.5528, -51.9253, 78.9629],
    'food_need': [2, 1, 4, 3, 5],
    'water_need': [3, 2, 5, 4, 6]
}
df = pd.DataFrame(data)

# Load world map data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge data with world map
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf = gdf.set_crs(epsg=4326)  # Set coordinate reference system

# Create a base map
m = folium.Map(location=[0, 0], zoom_start=2)

# Create heatmaps for food and water needs
HeatMap(data=gdf[['latitude', 'longitude', 'food_need']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=15, max_zoom=13).add_to(m)
HeatMap(data=gdf[['latitude', 'longitude', 'water_need']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=15, max_zoom=13, gradient={0.4: 'blue', 0.65: 'lime', 1: 'red'}).add_to(m)

# Display the map
m
# Out:
# ...
# <ipython-input-1-925546d6ac6e>:21: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-925546d6ac6e> in <cell line: 31>()
#      29
#      30 # Create heatmaps for food and water needs
# ---> 31 HeatMap(data=gdf[['latitude', 'longitude', 'food_need']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=15, max_zoom=13).add_to(m)
#      32 HeatMap(data=gdf[['latitude', 'longitude', 'water_need']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=15, max_zoom=13, gradient={0.4: 'blue', 0.65: 'lime', 1: 'red'}).add_to(m)
# ...

# %%
# prompt: write a programme which uses data from the web on world poverty, hunger, water availability and the global development indices. The code will then use machine learning to generate a world map of where food and water are needed.

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from sklearn.cluster import KMeans

# !pip install geopandas matplotlib folium

# Fetch data from reliable sources (replace with actual data sources)
# Example:
# poverty_data = pd.read_csv('https://example.com/poverty_data.csv')
# hunger_data = pd.read_csv('https://example.com/hunger_data.csv')
# water_data = pd.read_csv('https://example.com/water_availability_data.csv')
# development_data = pd.read_csv('https://example.com/global_development_indices.csv')

# Preprocess and merge the data (replace with actual data processing)
# Example:
# combined_data = pd.merge(poverty_data, hunger_data, on='country')
# combined_data = pd.merge(combined_data, water_data, on='country')
# combined_data = pd.merge(combined_data, development_data, on='country')

# Prepare data for machine learning
# Example:
# features = combined_data[['poverty_index', 'hunger_index', 'water_scarcity', 'development_index']]

# Apply KMeans clustering to identify areas with high need
# Example:
# kmeans = KMeans(n_clusters=3)  # Adjust number of clusters as needed
# combined_data['need_cluster'] = kmeans.fit_predict(features)

# Load world map data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge clustered data with world map
# Example:
# gdf = gpd.GeoDataFrame(combined_data, geometry=gpd.points_from_xy(combined_data.longitude, combined_data.latitude))
# gdf = gdf.set_crs(epsg=4326)

# Create a base map
m = folium.Map(location=[0, 0], zoom_start=2)

# Visualize clusters on the map (replace with actual visualization)
# Example:
# for cluster in gdf['need_cluster'].unique():
#     cluster_data = gdf[gdf['need_cluster'] == cluster]
#     folium.GeoJson(cluster_data, name=f'Cluster {cluster}').add_to(m)

# Display the map
m

# %%
# prompt: write a programme which analyses world development data. Then plots a world map with the areas shaded which need food and water.

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from sklearn.cluster import KMeans
from folium.plugins import HeatMap

# !pip install geopandas matplotlib folium

# Fetch data from reliable sources (replace with actual data sources)
# Example:
# poverty_data = pd.read_csv('https://example.com/poverty_data.csv')
# hunger_data = pd.read_csv('https://example.com/hunger_data.csv')
# water_data = pd.read_csv('https://example.com/water_availability_data.csv')
# development_data = pd.read_csv('https://example.com/global_development_indices.csv')

# Sample data (replace with real data)
data = {
    'country': ['USA', 'Canada', 'Mexico', 'Brazil', 'India'],
    'latitude': [37.0902, 56.1304, 23.6345, -14.2350, 20.5937],
    'longitude': [-95.7129, -106.3468, -102.5528, -51.9253, 78.9629],
    'food_need': [2, 1, 4, 3, 5],
    'water_need': [3, 2, 5, 4, 6]
}
df = pd.DataFrame(data)

# Load world map data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge data with world map
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf = gdf.set_crs(epsg=4326)  # Set coordinate reference system

# Create a base map
m = folium.Map(location=[0, 0], zoom_start=2)

# Create heatmaps for food and water needs
HeatMap(data=gdf[['latitude', 'longitude', 'food_need']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=15, max_zoom=13).add_to(m)
HeatMap(data=gdf[['latitude', 'longitude', 'water_need']].groupby(['latitude', 'longitude']).sum().reset_index().values.tolist(), radius=15, max_zoom=13, gradient={0.4: 'blue', 0.65: 'lime', 1: 'red'}).add_to(m)

# Display the map
m
# Out:
# ...
# <ipython-input-4-b7fc6d7dc30b>:30: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...
